# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir) 

from category import category

# %%
for i in category:
    print(category[i])
# Out:
# ['Analyzing and critiquing aesthetic qualities of photographs or other forms of art', 'Choreographing dance moves for a person to perform', 'Drawing or painting something (making art)', 'Picking a topic to write a short story about', 'Reviewing a book or a movie', 'Writing a blog post', 'Writing a novel or a short story (creative writing)']
# ['Analyzing and critiquing aesthetic qualities of photographs or other forms of art', 'Choreographing dance moves for a person to perform', 'Drawing or painting something (making art)', 'Picking a topic to write a short story about', 'Reviewing a book or a movie', 'Writing a blog post', 'Writing a novel or a short story (creative writing)', 'Cutting, drying, and styling hair, similar to what a barber or hairstylist might do', 'Designing new clothing to manufacture and sell (similar to what a fashion designer might do)']
# ...

# %%
import pandas as pd

# %%
america_personal = pd.read_csv("america-personal for process.csv")

# %%
# for index, row in america_personal.iterrows():
#     print(row)
#     print('------------------------------')

# code below iterate through pandas dataframe
for ind in america_personal.index:
    print(america_personal.iloc[ind]['task'])

# code below
# Out:
# Advising people on nutrition/their diet to help improve their health, similar to what a nutritionist might do
# Advising people on nutrition/their diet to help improve their health, similar to what a nutritionist might do
# Advising people on nutrition/their diet to help improve their health, similar to what a nutritionist might do
# Advising people on nutrition/their diet to help improve their health, similar to what a nutritionist might do
# Analyzing and controlling the flow of traffic in a city
# Analyzing and controlling the flow of traffic in a city
# Analyzing and controlling the flow of traffic in a city
# Analyzing and controlling the flow of traffic in a city
# Analyzing and controlling the flow of traffic in a city
# Analyzing and critiquing aesthetic qualities of photographs or other forms of art
# Analyzing and critiquing aesthetic qualities of photographs or other forms of art
# Analyzing and critiquing aesthetic qualities of photographs or other forms of art
# ...

# %%
columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','label']

# %%
# generate a list that consists of every row in dataframe
america_personal_list = []
for ind in america_personal.index:
    america_personal_list.append([america_personal.iloc[ind]['task'],america_personal.iloc[ind]['gender'],america_personal.iloc[ind]['age'],america_personal.iloc[ind]['tech-level'],america_personal.iloc[ind]['edu-level'],america_personal.iloc[ind]['d_social_skills'],america_personal.iloc[ind]['d_creativity'],america_personal.iloc[ind]['d_effort'],america_personal.iloc[ind]['d_expertise'],america_personal.iloc[ind]['d_abilities'],america_personal.iloc[ind]['r_accountable'],america_personal.iloc[ind]['r_uncertainty'],america_personal.iloc[ind]['r_impact'],america_personal.iloc[ind]['m_intrinsic'],america_personal.iloc[ind]['m_learning'],america_personal.iloc[ind]['m_important'],america_personal.iloc[ind]['t_machine_ability'],america_personal.iloc[ind]['t_process'],america_personal.iloc[ind]['t_values'],america_personal.iloc[ind]['Delegability']])
# print(america_personal_list)

# %%
dict_america_personal = {
    "art":[],
    "creative":[],
    "business":[],
    "civic":[],
    "social":[],
    "entertainment":[],
    "health":[],
    "living":[]
}

for idx in range(len(america_personal_list)):
    for kind in category:
        if america_personal_list[idx][0] in category[kind]:
            dict_america_personal[kind].append(america_personal_list[idx])
            break

# %%
processed_america_personal_list_art = dict_america_personal['art']
processed_america_personal_list_creative = dict_america_personal['creative']
processed_america_personal_list_business = dict_america_personal['business']
processed_america_personal_list_civic = dict_america_personal['civic']
processed_america_personal_list_social = dict_america_personal['social']
processed_america_personal_list_entertainment = dict_america_personal['entertainment']
processed_america_personal_list_health = dict_america_personal['health']
processed_america_personal_list_living = dict_america_personal['living']

# %%
america_personal_art = pd.DataFrame(processed_america_personal_list_art, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_creative = pd.DataFrame(processed_america_personal_list_creative, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_business = pd.DataFrame(processed_america_personal_list_business, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_civic = pd.DataFrame(processed_america_personal_list_civic, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_social = pd.DataFrame(processed_america_personal_list_social, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_entertainment = pd.DataFrame(processed_america_personal_list_entertainment, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_health = pd.DataFrame(processed_america_personal_list_health, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_living = pd.DataFrame(processed_america_personal_list_living, columns = ['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

# %%
america_personal_art.to_csv('categorized data/america personal/america_personal_art.csv')
america_personal_creative.to_csv('categorized data/america personal/america_personal_creative.csv')
america_personal_business.to_csv('categorized data/america personal/america_personal_business.csv')
america_personal_civic.to_csv('categorized data/america personal/america_personal_civic.csv')
america_personal_social.to_csv('categorized data/america personal/america_personal_social.csv')
america_personal_entertainment.to_csv('categorized data/america personal/america_personal_entertainment.csv')
america_personal_health.to_csv('categorized data/america personal/america_personal_health.csv')
america_personal_living.to_csv('categorized data/america personal/america_personal_living.csv')

# %% [markdown]
# # Below is for data category of japan personal

# %%
america_personal = pd.read_csv("japanese-personal for process.csv")

america_personal_list = []
for ind in america_personal.index:
    america_personal_list.append([america_personal.iloc[ind]['task'],america_personal.iloc[ind]['gender'],america_personal.iloc[ind]['age'],america_personal.iloc[ind]['tech-level'],america_personal.iloc[ind]['edu-level'],america_personal.iloc[ind]['d_social_skills'],america_personal.iloc[ind]['d_creativity'],america_personal.iloc[ind]['d_effort'],america_personal.iloc[ind]['d_expertise'],america_personal.iloc[ind]['d_abilities'],america_personal.iloc[ind]['r_accountable'],america_personal.iloc[ind]['r_uncertainty'],america_personal.iloc[ind]['r_impact'],america_personal.iloc[ind]['m_intrinsic'],america_personal.iloc[ind]['m_learning'],america_personal.iloc[ind]['m_important'],america_personal.iloc[ind]['t_machine_ability'],america_personal.iloc[ind]['t_process'],america_personal.iloc[ind]['t_values'],america_personal.iloc[ind]['Delegability']])

dict_america_personal = {
    "art":[],
    "creative":[],
    "business":[],
    "civic":[],
    "social":[],
    "entertainment":[],
    "health":[],
    "living":[]
}

for idx in range(len(america_personal_list)):
    for kind in category:
        if america_personal_list[idx][0] in category[kind]:
            dict_america_personal[kind].append(america_personal_list[idx])
            break

processed_america_personal_list_art = dict_america_personal['art']
processed_america_personal_list_creative = dict_america_personal['creative']
processed_america_personal_list_business = dict_america_personal['business']
processed_america_personal_list_civic = dict_america_personal['civic']
processed_america_personal_list_social = dict_america_personal['social']
processed_america_personal_list_entertainment = dict_america_personal['entertainment']
processed_america_personal_list_health = dict_america_personal['health']
processed_america_personal_list_living = dict_america_personal['living']

america_personal_art = pd.DataFrame(processed_america_personal_list_art, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_creative = pd.DataFrame(processed_america_personal_list_creative, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_business = pd.DataFrame(processed_america_personal_list_business, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_civic = pd.DataFrame(processed_america_personal_list_civic, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_social = pd.DataFrame(processed_america_personal_list_social, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_entertainment = pd.DataFrame(processed_america_personal_list_entertainment, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_health = pd.DataFrame(processed_america_personal_list_health, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_living = pd.DataFrame(processed_america_personal_list_living, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','m_intrinsic','m_learning','m_important','t_machine_ability','t_process','t_values','Delegability'])

america_personal_art.to_csv('categorized data/japanese personal/japan_personal_art.csv')
america_personal_creative.to_csv('categorized data/japanese personal/japan_personal_creative.csv')
america_personal_business.to_csv('categorized data/japanese personal/japan_personal_business.csv')
america_personal_civic.to_csv('categorized data/japanese personal/japan_personal_civic.csv')
america_personal_social.to_csv('categorized data/japanese personal/japan_personal_social.csv')
america_personal_entertainment.to_csv('categorized data/japanese personal/japan_personal_entertainment.csv')
america_personal_health.to_csv('categorized data/japanese personal/japan_personal_health.csv')
america_personal_living.to_csv('categorized data/japanese personal/japan_personal_living.csv')

# %% [markdown]
# # Below is for data category of japan expert

# %%
america_personal = pd.read_csv("japanese-expert for process.csv")

america_personal_list = []
for ind in america_personal.index:
    america_personal_list.append([america_personal.iloc[ind]['task'],america_personal.iloc[ind]['gender'],america_personal.iloc[ind]['age'],america_personal.iloc[ind]['tech-level'],america_personal.iloc[ind]['edu-level'],america_personal.iloc[ind]['d_social_skills'],america_personal.iloc[ind]['d_creativity'],america_personal.iloc[ind]['d_effort'],america_personal.iloc[ind]['d_expertise'],america_personal.iloc[ind]['d_abilities'],america_personal.iloc[ind]['r_accountable'],america_personal.iloc[ind]['r_uncertainty'],america_personal.iloc[ind]['r_impact'],america_personal.iloc[ind]['t_machine_ability'],america_personal.iloc[ind]['t_process'],america_personal.iloc[ind]['t_values'],america_personal.iloc[ind]['Delegability']])

dict_america_personal = {
    "art":[],
    "creative":[],
    "business":[],
    "civic":[],
    "social":[],
    "entertainment":[],
    "health":[],
    "living":[]
}

for idx in range(len(america_personal_list)):
    for kind in category:
        if america_personal_list[idx][0] in category[kind]:
            dict_america_personal[kind].append(america_personal_list[idx])
            break

processed_america_personal_list_art = dict_america_personal['art']
processed_america_personal_list_creative = dict_america_personal['creative']
processed_america_personal_list_business = dict_america_personal['business']
processed_america_personal_list_civic = dict_america_personal['civic']
processed_america_personal_list_social = dict_america_personal['social']
processed_america_personal_list_entertainment = dict_america_personal['entertainment']
processed_america_personal_list_health = dict_america_personal['health']
processed_america_personal_list_living = dict_america_personal['living']

america_personal_art = pd.DataFrame(processed_america_personal_list_art, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_creative = pd.DataFrame(processed_america_personal_list_creative, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_business = pd.DataFrame(processed_america_personal_list_business, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_civic = pd.DataFrame(processed_america_personal_list_civic, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_social = pd.DataFrame(processed_america_personal_list_social, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_entertainment = pd.DataFrame(processed_america_personal_list_entertainment, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_health = pd.DataFrame(processed_america_personal_list_health, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_living = pd.DataFrame(processed_america_personal_list_living, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_art.to_csv('categorized data/japanese expert/japan_expert_art.csv')
america_personal_creative.to_csv('categorized data/japanese expert/japan_expert_creative.csv')
america_personal_business.to_csv('categorized data/japanese expert/japan_expert_business.csv')
america_personal_civic.to_csv('categorized data/japanese expert/japan_expert_civic.csv')
america_personal_social.to_csv('categorized data/japanese expert/japan_expert_social.csv')
america_personal_entertainment.to_csv('categorized data/japanese expert/japan_expert_entertainment.csv')
america_personal_health.to_csv('categorized data/japanese expert/japan_expert_health.csv')
america_personal_living.to_csv('categorized data/japanese expert/japan_expert_living.csv')

# %% [markdown]
# # Below is for data category of america expert

# %%
america_personal = pd.read_csv("america-expert for process.csv")

america_personal_list = []
for ind in america_personal.index:
    america_personal_list.append([america_personal.iloc[ind]['task'],america_personal.iloc[ind]['gender'],america_personal.iloc[ind]['age'],america_personal.iloc[ind]['tech-level'],america_personal.iloc[ind]['edu-level'],america_personal.iloc[ind]['d_social_skills'],america_personal.iloc[ind]['d_creativity'],america_personal.iloc[ind]['d_effort'],america_personal.iloc[ind]['d_expertise'],america_personal.iloc[ind]['d_abilities'],america_personal.iloc[ind]['r_accountable'],america_personal.iloc[ind]['r_uncertainty'],america_personal.iloc[ind]['r_impact'],america_personal.iloc[ind]['t_machine_ability'],america_personal.iloc[ind]['t_process'],america_personal.iloc[ind]['t_values'],america_personal.iloc[ind]['Delegability']])

dict_america_personal = {
    "art":[],
    "creative":[],
    "business":[],
    "civic":[],
    "social":[],
    "entertainment":[],
    "health":[],
    "living":[]
}

for idx in range(len(america_personal_list)):
    for kind in category:
        if america_personal_list[idx][0] in category[kind]:
            dict_america_personal[kind].append(america_personal_list[idx])
            break

processed_america_personal_list_art = dict_america_personal['art']
processed_america_personal_list_creative = dict_america_personal['creative']
processed_america_personal_list_business = dict_america_personal['business']
processed_america_personal_list_civic = dict_america_personal['civic']
processed_america_personal_list_social = dict_america_personal['social']
processed_america_personal_list_entertainment = dict_america_personal['entertainment']
processed_america_personal_list_health = dict_america_personal['health']
processed_america_personal_list_living = dict_america_personal['living']

america_personal_art = pd.DataFrame(processed_america_personal_list_art, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_creative = pd.DataFrame(processed_america_personal_list_creative, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_business = pd.DataFrame(processed_america_personal_list_business, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_civic = pd.DataFrame(processed_america_personal_list_civic, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_social = pd.DataFrame(processed_america_personal_list_social, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_entertainment = pd.DataFrame(processed_america_personal_list_entertainment, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_health = pd.DataFrame(processed_america_personal_list_health, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_living = pd.DataFrame(processed_america_personal_list_living, columns=['task','gender','age','tech_level','edu_level','d_social_skills','d_creativity','d_effort','d_expertise','d_abilities','r_accountable','r_uncertainty','r_impact','t_machine_ability','t_process','t_values','Delegability'])

america_personal_art.to_csv('categorized data/america expert/america_expert_art.csv')
america_personal_creative.to_csv('categorized data/america expert/america_expert_creative.csv')
america_personal_business.to_csv('categorized data/america expert/america_expert_business.csv')
america_personal_civic.to_csv('categorized data/america expert/america_expert_civic.csv')
america_personal_social.to_csv('categorized data/america expert/america_expert_social.csv')
america_personal_entertainment.to_csv('categorized data/america expert/america_expert_entertainment.csv')
america_personal_health.to_csv('categorized data/america expert/america_expert_health.csv')
america_personal_living.to_csv('categorized data/america expert/america_expert_living.csv')
